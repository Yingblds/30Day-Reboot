# %% [markdown]
# # Data Inspection
#
# **Goal:**
# Understand the structure of the dataset before performing any analysis.
#
# **Data Source:** [Seaborn tips dataset](https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv)
#
# **Steps:**
# - Load dataset into pandas DataFrame
# - Inspect first rows
# - Check column types and missing values
# - Generate summary statistics

# %%
# Import library
import pandas as pd
import matplotlib.pyplot as plt

print("Enviroment is ready. Project started.")
# Out:
# Enviroment is ready. Project started.

# %%
import pandas as pd

# Load dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

# Inspect
print("First 5 rows:")
print(df.head())

print("\nDataset info:")  # \n -- Add a blank line before the output
print(df.info())

print("\nDataset description:")
print(df.describe())
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None
#
# Dataset description:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Inspect
print("First 5 rows:")
df.head() #return DataFrame, need to wrap it with print() or place it in a separate cell in order to display this one.

print("\nDataset info:")  # \n -- Add a blank line before the output
df.info() #prints directly to stdout internally, so it is shown even if it is not the last line.

print("\nDataset description:")
df.describe() #return DataFrame, in a Jupyter or VS Code notebook, only the last expression in a cell is automatically rendered.Since df.describe() ist the last line, only its output is displayed.
# Out:
# First 5 rows:
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
#
# Dataset description:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Inspect
print("First 5 rows:")
print(df.head())

print("\nDataset info:")  # \n -- Add a blank line before the output
df.info()

print("\nDataset description:")
df.describe()
# Out:
# First 5 rows:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
#
# Dataset description:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Data Cleaning
#
# **Goal:**
# Check data quality and prepare the dataset for analysis.
#
# **Steps:**
# 1. Check missing values
# 2. Check duplicate rows
# 3. Validate data types
# 4. Perform basic cleaning

# %%
# Check missing value
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# No missing values were detected in the dataset.

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# One duplicate row was detected in the dataset.
#
# The duplicate entry is removed using "drop_duplicates()"

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# Check duplicates in order to make sure that they all have been successfully removed
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check number of rows after removing duplicates
df.shape
# Out:
# (243, 7)

# %% [markdown]
# After removing one duplicate row, the dataset contains 243 observations.

# %%
# Check data types
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %% [markdown]
# The data types of all variables appear appropriate for analysis.

# %%
# Save the cleaned dataset
df.to_csv("tips_cleaned.csv", index=False)

# %% [markdown]
# A cleaned version of the dataset was saved for further analysis.

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# **Goal:**
# Explore the dataset to understand distributions, relationships, and patterns in the data.
#
# **Steps:**
# 1. Compute summary statistics for numeric variables ('total_bill', 'tip', 'size').
# 2. Analyze categorical variables ('day', 'time', 'sex', 'smoker') and their distributions.
# 3. Examine relationships between key variables (e.g., 'total_bill' vs 'tip', 'size' vs 'tip').
# 4. Visualize distributions and relationships using plots (histograms, boxplots, scatterplots).
# 5. Identify and patterns, trends, or anomalies that may influence further analysis.

# %%
# Summary statistics for numeric variables
df.describe()
# Out:
#        total_bill         tip        size
# count  243.000000  243.000000  243.000000
# mean    19.813868    3.002387    2.572016
# std      8.910071    1.385002    0.952356
# min      3.070000    1.000000    1.000000
# 25%     13.380000    2.000000    2.000000
# 50%     17.810000    2.920000    2.000000
# 75%     24.175000    3.575000    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Numeric Summary
# The summary statistics provide insights into the distribution of numeric variables like total_bill, tip, and size.

# %%
# Count of each category
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    61
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      67
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     86
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     92
# Name: count, dtype: int64

# %% [markdown]
# ## Categorical Summary
# This shows the frequency of each category for day, time, sex and smoker status.

# %%
# Average tip by day
df.groupby("day")["tip"].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.784098
# Name: tip, dtype: float64

# %% [markdown]
# ### Average Tip by day
# The average tip on Friday is approximately **2.73**, on Saturday it is about **2.99**, on Sunday it is around **3.26**, while on Thursday it is about **2.78**.
# This suggests that customers tend to leave a slightly higher tips on Sunday among all of four days.

# %%
# Average tip by time
df.groupby("time")["tip"].mean()
# Out:
# time
# Dinner    3.102670
# Lunch     2.738955
# Name: tip, dtype: float64

# %% [markdown]
# ### Average Tip by Meal Time
# The average tip during dinner is approximately **3.10**, while during lunch it is about **2.74**.
# This suggests that customers tend to leave slightly higher tips during dinner compared to lunch.

# %%
# Average total_bill by time
df.groupby("time")["total_bill"].mean()
# Out:
# time
# Dinner    20.797159
# Lunch     17.230896
# Name: total_bill, dtype: float64

# %% [markdown]
# ### Average total bill by Meal Time
# The average total bill during dinner is approximately **20.80**, while during lunch it is about **17.23**. This suggests that customers spend more during dinner compared with lunch.
# This may partly explain why the average tip during dinner is higher, since larger bills are typically associated with higher tipping amounts.

# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/opt/python@3.10/bin/python3.10

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/homebrew/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/homebrew/lib/python3.10/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/homebrew/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /opt/homebrew/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/honeybee/Library/Python/3.10/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /Users/honeybee/Library/Python/3.10/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/honeybee/Library/Python/3.10/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: six>=1.5 in /Users/honeybee/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip available: 22.2.2 -> 26.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot: total_bill vs tip, color by time
sns.scatterplot(x='total_bill', y='tip', hue='time', data=df)
plt.title("Tip vs Total Bill by Meal Time")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.show()

# %% [markdown]
# ### Observations:
# 1. Tips generally increase as total bill increases, indicating a positive relationship between bill size and tipping amount.
# 2. The scatterplot dose not reveal extreme outliers, and the tipping behavior seems relatively consistent across the dataset.
# 3. The difference in tipping behavior between lunch and dinner is not very pronounced in the scatterplot, suggesting that meal time alone may not strongly influence tipping patterns.

# %%
# Boxplot: tip by day
sns.boxplot(x='day', y='tip', data=df, order=["Thur", "Fri", "Sat", "Sun"])
plt.title("Tip vs Day")
plt.xlabel("Day")
plt.ylabel("Tip ($)")
plt.show()

# %% [markdown]
# ### Observations:
# 1. Saturday's tip distribution shows the highest number of outliers.
# 2. Sunday exhibits a higher median tip value compared to other days.
